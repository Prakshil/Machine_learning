# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakshil/Machine_learning/blob/main/Practical2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
column_names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "car name"]

# %%
df = pd.read_csv(data_url, names=column_names, delim_whitespace=True, na_values="?")
df.head(10)
# Out:
# /tmp/ipython-input-3-822219207.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(data_url, names=column_names, delim_whitespace=True, na_values="?")
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
# 5  15.0          8         429.0       198.0  4341.0          10.0
# 6  14.0          8         454.0       220.0  4354.0           9.0
# 7  14.0          8         440.0       215.0  4312.0           8.5
# 8  14.0          8         455.0       225.0  4425.0          10.0
# ...

# %%
plt.scatter(df["mpg"], df["cylinders"])
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
# Out:
# Text(0, 0.5, 'Y-axis Label')

# %%
plt.hist(df["mpg"])
# Out:
# (array([13., 78., 73., 61., 54., 48., 38., 22.,  5.,  6.]),
#  array([ 9.  , 12.76, 16.52, 20.28, 24.04, 27.8 , 31.56, 35.32, 39.08,
#         42.84, 46.6 ]),
#  <BarContainer object of 10 artists>)

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
column_name=["speal_length","sepal_width","petal_length","petal_width","class"]

# %%
df = pd.read_csv(url, names=column_name, delimiter="," , na_values="?")
df.head(10)
# Out:
#    speal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
plt.scatter(df["petal_width"], df["sepal_width"])
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
# Out:
# Text(0, 0.5, 'Y-axis Label')
